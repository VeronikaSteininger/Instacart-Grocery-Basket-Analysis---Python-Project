# %% [markdown]
# LIST OF CONTENT - Deriving New Variables
#
# 1. preparations
# 2. user-defined functions
# 3. different method with df.loc
#    - using reduced dataset
# 4. identify the busiest and least busiest day and mark them with a flag
#    - with 'for loop'
# 5. different version of calculating days
# 6. identify the busiest period of the day

# %% [markdown]
# # 1. preparations

# %%
import pandas as pd
import numpy as np
import os

# %%
path=r'/Users/ru/Desktop/CF/04 Achievement 4_Python'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path,
'02_Data','2.2 Prepared Data', 'ords_prods_merge_4.6.pkl'))

# %%
# fokus on the first million entries
df = ords_prods_merge[:1000000]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'product_id', 'product_name', 'aisle_id', 'department_id',
#        'prices', 'order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'last_order (in days)', 'add_to_cart_order',
#        'reordered', '_merge'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# # 2. user-defined functions

# %%
# sorting prices acording to three categories
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/ds/6109zp994ddgpkwq7qfc1y3c0000gp/T/ipykernel_15727/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product    634889
# Low-range product    331220
# Not enough data       24547
# High range             9344
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %% [markdown]
# I come here to different results than described in the exercise. Is it possible that the dataset was manipulated over the time? It would not be the first time that I have the impression that the description in the exercise does not fit exactly with the givern material.

# %% [markdown]
# # 3. different method with df.loc

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/ds/6109zp994ddgpkwq7qfc1y3c0000gp/T/ipykernel_15727/1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     634889
# Low-range product     331220
# NaN                    24547
# High-range product      9344
# Name: count, dtype: int64

# %%
# checking results with the whole dataset
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     21860868
# Low-range product     10126324
# High-range product      417678
# NaN                      30200
# Name: count, dtype: int64

# %%
#checking size
ords_prods_merge.shape
# Out:
# (32435070, 16)

# %% [markdown]
# # 4. identify the busiest and least busiest day and mark them with a flag

# %%
# identify which days have the highest or lowest frequency:
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0.0    6209808
# 1.0    5665951
# 6.0    4500391
# 2.0    4217868
# 5.0    4209603
# 3.0    3844175
# 4.0    3787263
# NaN         11
# Name: count, dtype: int64

# %%
# for loop
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# defining column for results
ords_prods_merge['busiest day']= result

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# check outcome
ords_prods_merge['busiest day'].value_counts(dropna=False)
# Out:
# busiest day
# Regularly busy    22437999
# Busiest day        6209808
# Least busy         3787263
# Name: count, dtype: int64

# %% [markdown]
# # 5. different version of calculating days

# %% [markdown]
# # for loop
# result = []
#
# for value in ords_prods_merge["orders_day_of_week"]:
#   if value == 0:
#     result.append("Busiest day")
#   elif value == 4:
#     result.append("Least busy")
#   else:
#     result.append("Regularly busy")

# %%
result_2 = [ ]

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_2.append("Busiest day")
  elif value == 4 or value == 3:
    result_2.append("Least busy")
  else:
    result_2.append("Regularly busy")

# %%
# defining column for result_2
ords_prods_merge['busiest days'] = result_2

# %%
# check outcome
ords_prods_merge['busiest days'].value_counts(dropna=False)
# Out:
# busiest days
# Regularly busy    12927873
# Busiest day       11875759
# Least busy         7631438
# Name: count, dtype: int64

# %% [markdown]
# the two variations 'busiest day' and 'least busy' and the two 'busiest days' and two 'least busiesd days' lead, as expected to the same total number.

# %% [markdown]
# # 6. identify the busiest period of the day

# %%
# check which coulumn is relevant
ords_prods_merge.columns
# Out:
# Index(['Unnamed: 0', 'product_id', 'product_name', 'aisle_id', 'department_id',
#        'prices', 'order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'last_order (in days)', 'add_to_cart_order',
#        'reordered', '_merge', 'price_range_loc', 'busiest day',
#        'busiest days'],
#       dtype='object')

# %%
# check results of the particular column
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10.0    2764476
# 11.0    2738647
# 14.0    2691598
# 15.0    2664583
# 13.0    2663346
# 12.0    2620898
# 16.0    2537506
# 9.0     2456751
# 17.0    2089510
# 8.0     1719991
# 18.0    1637956
# 19.0    1259416
# 20.0     977049
# 7.0      891951
# 21.0     796379
# 22.0     634743
# 23.0     402621
# 6.0      290796
# 0.0      218951
# 1.0      115787
# 5.0       88064
# 2.0       69435
# 4.0       53284
# 3.0       51321
# NaN          11
# Name: count, dtype: int64

# %%
# devision into time periods: 8 am to 4pm: 'Most Orders' 5pm to 11 pm: 'Average Orders'  0 am to 7 am: 'Fewest Orders'
result_1 = []

for value in ords_prods_merge['order_hour_of_day']:
  if value == 8 or value == 9 or value == 10 or value == 11 or value == 12 or value == 13 or value == 14 or value == 15 or value == 16 or value:
    result_1.append ('Most Orders')
  elif value == 0 or value == 1 or value == 2 or value == 3 or value == 4 or value == 5 or value == 6 or value == 7:
    result_1.append('Fewest Orders')
  else:
    result_1.append('Average Orders')

# %%
ords_prods_merge['Most Orders']= result_1

# %%
# check results
ords_prods_merge['Most Orders'].value_counts(dropna=False)
# Out:
# Most Orders
# Most Orders      32216119
# Fewest Orders      218951
# Name: count, dtype: int64

# %%
# export notebook
ords_prods_merge.to_pickle(os.path.join(path, '02_Data','2.2 Prepared Data', 'ords_prods_merge_4.7.pkl'))

# %%
ords_prods_merge.columns
# Out:
# Index(['Unnamed: 0', 'product_id', 'product_name', 'aisle_id', 'department_id',
#        'prices', 'order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'last_order (in days)', 'add_to_cart_order',
#        'reordered', '_merge', 'price_range_loc', 'busiest day', 'busiest days',
#        'Most Orders'],
#       dtype='object')
